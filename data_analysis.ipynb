# %%
import pandas as pd

# %% [markdown]
# import the parquet file into pandas and check the table

# %%
df = pd.read_csv('ednet_subset.csv')

df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 132851 entries, 0 to 132850
# Data columns (total 5 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   CAST("timestamp" AS BIGINT)    132851 non-null  int64
#  1   CAST(solving_id AS INTEGER)    132851 non-null  int64
#  2   question_id                    132851 non-null  str
#  3   user_answer                    132842 non-null  str
#  4   CAST(elapsed_time AS INTEGER)  132851 non-null  int64
# dtypes: int64(3), str(2)
# memory usage: 5.8 MB
